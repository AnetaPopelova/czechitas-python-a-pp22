# %% [markdown]
# # pandas.DataFrame.shape

# %%
import pandas as pd

## Nejlepsi filmy podle IMDB
df = pd.DataFrame({
                'movie_name': ["The Shawshank Redemption", 
                                "The Godfather", 
                                "The Dark Knight"], 
                'rating': [9.2, 9.2, 9.0]})
df
# Out:
#                  movie_name  rating
# 0  The Shawshank Redemption     9.2
# 1             The Godfather     9.2
# 2           The Dark Knight     9.0

# %%
df.shape
# Out:
# (3, 2)

# %%
df.shape[0]
# Out:
# 3

# %%
df.shape[1]
# Out:
# 2
